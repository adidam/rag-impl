# %% [markdown]
# <a href="https://colab.research.google.com/github/adidam/rag-impl/blob/main/rag_visualizer_venkat_for_metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Setup steps for pip install and copy db file**

# %%
# !pip install rank_bm25
# !pip install datasets
# !pip install gradio
# !pip install pymilvus pymilvus[model]
# !pip install langchain_groq
# !pip install nltk

from google.colab import drive
drive.mount('/content/drive')

# !ls -l
# !cp /content/drive/MyDrive/ragbench.db /content/ragbench.db
# !ls -l
# Out:
# Requirement already satisfied: rank_bm25 in /usr/local/lib/python3.11/dist-packages (0.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rank_bm25) (1.26.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.3.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.12)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: gradio in /usr/local/lib/python3.11/dist-packages (5.16.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.115.8)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.7.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (1.7.1)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.1.5)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.10.15)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.10.6)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.9.7)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.45.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.7.1->gradio) (2024.10.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.7.1->gradio) (14.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (3.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio) (2.27.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: pymilvus in /usr/local/lib/python3.11/dist-packages (2.5.4)
# Requirement already satisfied: setuptools>69 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (75.1.0)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (1.67.1)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (4.25.6)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (1.0.1)
# Requirement already satisfied: ujson>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (2.2.2)
# Requirement already satisfied: milvus-lite>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus) (2.4.11)
# Requirement already satisfied: milvus-model>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from pymilvus[model]) (0.2.12)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from milvus-lite>=2.4.0->pymilvus) (4.67.1)
# Requirement already satisfied: transformers>=4.36.0 in /usr/local/lib/python3.11/dist-packages (from milvus-model>=0.1.0->pymilvus[model]) (4.48.3)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.11/dist-packages (from milvus-model>=0.1.0->pymilvus[model]) (1.20.1)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from milvus-model>=0.1.0->pymilvus[model]) (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from milvus-model>=0.1.0->pymilvus[model]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.4->pymilvus) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (0.28.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (0.5.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (25.2.10)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (1.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (4.12.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.0->milvus-model>=0.1.0->pymilvus[model]) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime->milvus-model>=0.1.0->pymilvus[model]) (1.3.0)
# Requirement already satisfied: langchain_groq in /usr/local/lib/python3.11/dist-packages (0.2.4)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from langchain_groq) (0.18.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.33 in /usr/local/lib/python3.11/dist-packages (from langchain_groq) (0.3.35)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.4.1->langchain_groq) (4.12.2)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_groq) (0.3.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_groq) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_groq) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.33->langchain_groq) (24.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain_groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.33->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain_groq) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.33->langchain_groq) (2.3.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Mounted at /content/drive
# total 8
# drwx------ 7 root root 4096 Feb 20 18:39 drive
# drwxr-xr-x 1 root root 4096 Feb 19 18:25 sample_data
# total 92544
# drwx------ 7 root root     4096 Feb 20 18:39 drive
# -rw------- 1 root root 94752768 Feb 20 18:39 ragbench.db
# drwxr-xr-x 1 root root     4096 Feb 19 18:25 sample_data

# %%
import os
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from transformers import AutoTokenizer
from nltk.tokenize import sent_tokenize
from torch.utils.data import random_split
from torchvision import datasets, transforms, models
from sentence_transformers import SentenceTransformer
import nltk

nltk.download('punkt_tab')

# embedding_model = "sentence-transformers/all-MiniLM-L6-v2"
embedding_model = "BAAI/LLM-Embedder"
# embedding_model = "BAAI/bge-large-en"

# Initialize the tokenizer
tokenizer = AutoTokenizer.from_pretrained(embedding_model)
embedder = SentenceTransformer(embedding_model)  # Pretrained sentence transformer
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/396 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/28.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # **Tokenization and other utility functions**

# %%
# New code - 12/4 10 pm
import hashlib
from rank_bm25 import BM25Okapi
from nltk.tokenize import word_tokenize
import scipy.sparse as sp

# Initialize the tokenizer
#tokenizer = AutoTokenizer.from_pretrained(embedding_model)
#tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")

# Sliding window configuration
TOKEN_LIMIT = 512
SLIDING_WINDOW_OVERLAP = 100  # Overlap between consecutive chunks (in tokens)

# Function for chunking with token limit and sliding window
def chunk_with_token_limit(text, token_limit=512, overlap=100):
    sentences = sent_tokenize(text)  # Split text into sentences
    chunks = []  # Store resulting chunks
    current_chunk = []  # Temporarily hold sentences for the current chunk
    current_chunk_tokens = 0  # Token count for the current chunk

    for sentence in sentences:
        # Tokenize the sentence and calculate its token count
        sentence_tokens = tokenizer.tokenize(sentence)
        num_tokens = len(sentence_tokens)

        # print(f"Tokens: {sentence_tokens[0]}")

        # If adding this sentence exceeds the token limit
        if current_chunk_tokens + num_tokens > token_limit:
            # Save the current chunk
            chunk_text = " ".join(current_chunk)
            chunks.append(chunk_text)

            # Prepare the next chunk with overlap
            overlap_tokens = tokenizer.tokenize(" ".join(current_chunk[-1:]))
            current_chunk = [sentence for sentence in current_chunk[-(overlap // len(overlap_tokens)) :]] if current_chunk else []
            current_chunk_tokens = sum(len(tokenizer.tokenize(sent)) for sent in current_chunk)

        # Add the sentence to the current chunk
        current_chunk.append(sentence)
        current_chunk_tokens += num_tokens

    # Add the last chunk if it exists
    if current_chunk:
        chunk_text = " ".join(current_chunk)
        chunks.append(chunk_text)

    return chunks

def process_document_with_identifiers(document):
    processed_data = []
    title_count = -1  # to start from 0
    # print("document>>>>>>>",document)
    for section in document:
        section_chunks = []
        passage_count = [ord('a')]  # Passage identifier as a list to handle nested increments
        title_count += 1  # Increment title count

        # Tokenize the section into sentences
        sentences = sent_tokenize(section)
        for sentence in sentences:
            if sentence.startswith("Title:"):
                # New document detected
                identifier = f"{title_count}{''.join(chr(c) for c in passage_count)}"  # Identifier for the title

                # Commented this line to integrate and test with small to big. To be uncommented after testing
                chunked_texts = chunk_with_token_limit(sentence, TOKEN_LIMIT, SLIDING_WINDOW_OVERLAP)

                #Added this line to replace sliding window tokenization with hybrid tokenization (sliding window + small-to-big)
                #chunked_texts = hybrid_chunking(sentence,tokenizer, TOKEN_LIMIT, SLIDING_WINDOW_OVERLAP)

                for chunk in chunked_texts:
                    section_chunks.append([identifier, chunk])
                passage_count = [ord('a')]  # Reset passage count for the new document
            else:
                # Sentence under the current document
                identifier = f"{title_count}{''.join(chr(c) for c in passage_count)}"

                # Commented this line to integrate and test with small to big. To be uncommented after testing
                chunked_texts = chunk_with_token_limit(sentence, TOKEN_LIMIT, SLIDING_WINDOW_OVERLAP)

                #Added this line to replace sliding window tokenization with hybrid tokenization (sliding window + small-to-big)
                #chunked_texts = hybrid_chunking(sentence,tokenizer, TOKEN_LIMIT, SLIDING_WINDOW_OVERLAP)
                #print("chunked_texts>>>>process_document_with_identifiers>>>>> "+ "".join(chunked_texts))

                for chunk in chunked_texts:
                    section_chunks.append([identifier, chunk])

                # Increment passage_count intelligently
                i = len(passage_count) - 1
                while i >= 0:
                    passage_count[i] += 1
                    if passage_count[i] > ord('z'):
                        passage_count[i] = ord('a')
                        if i == 0:
                            passage_count.insert(0, ord('a'))  # Add a new character to the identifier
                        i -= 1
                    else:
                        break


        #print("section_chunks>>>>>>>",section_chunks)
        processed_data.append(section_chunks)

    return processed_data

# Function to generate a hash based on content and key metadata
def generate_hash(content, metadata):
    """Generate a unique hash for the document content and key metadata."""
    key_fields = f"{content}|{metadata.get('item_index')}|{metadata.get('prefix')}"
    return hashlib.md5(key_fields.encode('utf-8')).hexdigest()

# Function to retrieve existing hashes from the database
def get_existing_hashes(collection):
    """Retrieve all existing hashes (IDs) currently in the database."""
    all_records = collection.get(include=["documents", "metadatas"])  # Fetch documents and metadata
    existing_hashes = set()
    for doc, metadata in zip(all_records["documents"], all_records["metadatas"]):
        doc_hash = generate_hash(doc, metadata)
        existing_hashes.add(doc_hash)
    return existing_hashes

# Function to retrieve existing hashes from the database
def get_existing_hashes_milvus(all_records):
    """Retrieve all existing hashes (IDs) currently in the database."""
    existing_hashes = set()
    print(f"all records >>> {len(all_records)}")
    if all_records == None or len(all_records) == 0:
        return existing_hashes

    for record in all_records:
        doc = record.get("documents")
        metadata = record.get("metadata")
        doc_hash = generate_hash(doc, metadata)
        existing_hashes.add(doc_hash)
    return existing_hashes

def flatten_array(array):
    """Flatten a 2D array into a 1D array."""
    data = []
    for item in array:
        if isinstance(item, list):
            data.extend(flatten_array(item))
        else:
            data.append(item)
    return data

def fetch_complete_docs(milvus_collection_name):
    """Fetch all documents from the database."""
    results = flatten_array(
        datastor.extract_documents(
            datastor.get_all_records(milvus_collection_name)))
    return results

def extract_text(data):
    """ contatenate all string in array """
    text = " ".join(data)

# Tokenize corpus and prepare BM25 encoder
def prepare_bm25_encoder(texts):
    tokenized_corpus = [word_tokenize(text.lower()) for text in texts]
    bm25_encoder = BM25Okapi(tokenized_corpus)
    return bm25_encoder

def generate_sparse_vector_bm25(query, bm25_encoder):
    tokenized_query = word_tokenize(query.lower())
    scores = bm25_encoder.get_scores(tokenized_query)
    # Convert scores to CSR format
    sparse_vector = sp.csr_matrix(scores)
    return sparse_vector

# %% [markdown]
# ## **Milvus VectorDataStore class**

# %%
import numpy as np
import time
from pymilvus import connections
from pymilvus import FieldSchema, CollectionSchema, DataType, Collection
from pymilvus import MilvusClient
from pymilvus import utility

class VectorDataStore:
    db_url = "http://localhost:19530"

    #description = f"collection created for {self.name}"

    def __init__(self, path="/content/ragbench.db"):
        self.client = MilvusClient(path)

    def get_or_create_collection(self, name, vec_dim=128):
        try:
            self.get_collection(name)
        except:
            print(f"Collection {name} doesn't exist. Creating...")
            self.create_collection(name, vec_dim)


    def create_collection(self, name, vec_dim=128):
        if self.client.has_collection(name):
            self.default_collection_name = name

        self.description = f"collection to store {name}"

        index_params = self.client.prepare_index_params()
        index_params.add_index(
            field_name="embedding",
            index_type="AUTOINDEX",
            metric_type="COSINE"
        )
        index_params.add_index(
            field_name="sparse",
            index_type="SPARSE_INVERTED_INDEX",
            metric_type="IP"
        )
        schema = self.client.create_schema(
            auto_id=False,
            enable_dynamic_fields=True,
        )
        schema.add_field(field_name="pk", datatype=DataType.VARCHAR, max_length=64, is_primary=True)
        schema.add_field(field_name="metadata", datatype=DataType.JSON)
        schema.add_field(field_name="documents", datatype=DataType.VARCHAR, max_length=512)
        schema.add_field(field_name="sparse", datatype=DataType.SPARSE_FLOAT_VECTOR)
        schema.add_field(field_name="embedding", datatype=DataType.FLOAT_VECTOR, dim=vec_dim)

        collection = self.client.create_collection(collection_name=name,
                                       schema=schema,
                                       index_params=index_params)
        self.current_collection = collection
        return collection


    def get_collection(self, name):
        if not self.client.has_collection(name):
            raise ValueError(f"Collection '{name}' does not exist.")
        self.current_collection = Collection(name)
        return self.current_collection

    def get_all_records(self, collection):
        all_records = self.client.query(
            collection_name=collection,
            filter=None,
            output_fields=["documents", "metadata"],
            limit=10000
        )
        if all_records == None:
            all_records = []

        return all_records

    def has_entities(self, name):
        if not self.client.has_collection(name):
            raise ValueError(f"Collection '{name}' does not exists.")
        self.default_collection = name
        collection_stats = self.client.get_collection_stats(name)
        count = collection_stats.get("row_count", 0)  # Retrieve the number of entities
        return count

    def insert(self, collection_name: str, metadata: list[dict[str, any]],
                documents: list[str], sparse_embs: np.ndarray, embeddings: np.ndarray, ids: list[int]):

        if not self.client.has_collection(collection_name):
            raise ValueError(f"Collection '{collection_name}' does not exist. Create it first.")

        if len(metadata) != len(embeddings) != len(documents) != len(ids):
           raise ValueError("Metadata, documnets, ids and embeddings must have the same length.")

        data = []
        for meta, doc, sp_embs, emb, id in zip(metadata, documents, sparse_embs, embeddings, ids):
          datum = {
              "pk": id,
              "metadata": meta,
              "documents": doc,
              "sparse": sp_embs,
              "embedding": emb.tolist(),
          }
          data.append(datum)

        self.client.insert(collection_name, data)
        print(f"Inserted {len(metadata)} records into collection '{collection_name}'.")

    def drop_collection(self, collection_name: str):
        if not self.client.has_collection(collection_name):
            raise ValueError(f"Collection '{collection_name}' does not exist.")
        self.client.drop_collection(collection_name)
        print(f"Dropped collection '{collection_name}'.")

    def delete_all(self, collection_name: str):
        if not self.client.has_collection(collection_name):
            raise ValueError(f"Collection '{collection_name}' does not exist.")
        self.client.delete(collection_name, expr="pk >= 0")
        self.client.flush([collection_name])

    def search(self, query_embedding: np.ndarray, collection='all', top_k: int = 10) -> list[dict[str, any]]:
        """
        Search across all collections for the top-k closest embeddings.
        :param query_embedding: The embedding vector to search for.
        :param top_k: Number of top results to retrieve.
        :return: A list of dictionaries containing collection name, id, metadata, and distance.
        """
        results = []
        if collection=='all':
          collections = self.client.list_collections()
        else:
          collections = [collection]

        start_time = time.time()
        for collection_name in collections:
            if not self.client.has_collection(collection_name):
                continue

            # Set params to COSINE to match chromadb
            search_params = {"metric_type": "COSINE", "params": {"ef": 128}}

            search_results = self.client.search(
                collection_name=collection_name,
                data=[query_embedding],
                anns_field="embedding",
                search_params=search_params,
                limit=top_k,
                output_fields=["metadata", "documents"]
            )

            print(f"search results size : {len(search_results)}")

            for hits in search_results:
                for hit in hits:
                    print(f"Collection: {collection_name}, data: {str(hit)}")
                    results.append({
                        "collection": collection_name,
                        "id": hit["id"],
                        "metadata": hit["entity"]["metadata"],
                        "distance": hit["distance"],
                        "documents": hit["entity"]["documents"]
                      })

        results = sorted(results, key=lambda x: x["distance"])[:top_k]
        end_time = time.time()
        print(f"Search completed. Found {len(results)} results. in {end_time - start_time} secs")
        return results

    def sparse_search(self, query_embedding: np.ndarray, collection='all', top_k : int=10)-> list[dict[str, any]] :
        results = []
        if (collection=='all'):
          collections = self.client.list_collections()
        else:
          collections = [collection]
        start_time = time.time()
        for collection_name in collections:
            if not self.client.has_collection(collection_name):
                continue

            # Set params to COSINE to match chromadb
            search_params = {"metric_type": "IP", "params": {"ef": 128}}

            search_results = self.client.search(
                collection_name=collection_name,
                data=[query_embedding],
                anns_field="sparse",
                search_params=search_params,
                limit=top_k,
                output_fields=["metadata", "documents"]
            )

            print(f"search results size : {len(search_results)}")

            for hits in search_results:
                for hit in hits:
                    print(f"Collection: {collection_name}, data: {str(hit)}")
                    results.append({
                        "collection": collection_name,
                        "id": hit["id"],
                        "metadata": hit["entity"]["metadata"],
                        "distance": hit["distance"],
                        "documents": hit["entity"]["documents"]
                      })

        results = sorted(results, key=lambda x: x["distance"])[:top_k]
        end_time = time.time()
        print(f"Search completed. Found {len(results)} results. in {end_time - start_time} secs")
        return results

    def hybrid_search(self, sparse_query_embedding: np.ndarray, dense_query_embedding: np.ndarray, collection='all', top_k : int=10, alpha=0.3)-> list[dict[str, any]] :
        results = []
        start_time = time.time()
        sparse_results = self.sparse_search(sparse_query_embedding, collection, top_k)
        n = int(len(sparse_results) * alpha)
        alpha_sparse_results = sparse_results[:n]
        dense_results = self.search(dense_query_embedding, collection, top_k)
        #'results = sorted(results, key=lambda x: x["distance"])[:top_k]
        results = dense_results + alpha_sparse_results
        end_time = time.time()
        print(f"Hybrid Search completed. Found {len(results)} results. in {end_time - start_time} secs")
        return results

    def extract_documents(self, search_results: list[dict[str, any]]) -> list[np.ndarray]:
      """
      Extract embedding values from search results.
      :param search_results: List of dictionaries containing search results.
      :return: List of embedding vectors as NumPy arrays.
      """
      return [result["documents"] for result in search_results if "documents" in result]

# %%
datasets = ['covidqa','cuad','delucionqa','emanual','expertqa','finqa','hagrid','hotpotqa','msmarco','pubmedqa','tatqa','techqa']
datastor = VectorDataStore()

insert_data = True
store_client = "Milvus"
num_records = 0

vector_dim = embedder.get_sentence_embedding_dimension()

# %%
collections = datastor.client.list_collections()
print("collections>>> ",collections)
# Out:
# collections>>>  ['ragbench_collection_covidqa', 'ragbench_collection_cuad', 'ragbench_collection_delucionqa', 'ragbench_collection_emanual', 'ragbench_collection_expertqa', 'ragbench_collection_finqa', 'ragbench_collection_hagrid', 'ragbench_collection_hotpotqa', 'ragbench_collection_msmarco', 'ragbench_collection_pubmedqa', 'ragbench_collection_tatqa', 'ragbench_collection_techqa']

# %% [markdown]
# # **Index Data into DB**

# %% [markdown]
# ## **Don't run this everytime**

# %%
from datasets import load_dataset
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
import random

# Initialize storage for documents, IDs, and metadata

for i in range(12):
  all_documents = []
  all_ids = []
  all_metadatas = []

  # Process each dataset
  doc_idx = 0  # Global document index for unique IDs
  for dataset in [datasets[i]]:
      milvus_collection_name = f"ragbench_collection_{dataset}"
      try:
        num_records = datastor.has_entities(milvus_collection_name)
      except:
        num_records = 0
        print("we are good. collection doesnt exists")

      if num_records > 0:
          datastor.drop_collection(milvus_collection_name)

      datastor.get_or_create_collection(milvus_collection_name, vector_dim)

      print(f"Processing {dataset}...")
      data = load_dataset("rungalileo/ragbench", dataset, split="train")
      #only select first 5 records for debugging duplicate records. **PLEASE REMOVE THIS AFTER DEBUGGING**
      data = data.select(range(10))
      for idx, row in tqdm(enumerate(data), desc=f"Processing {dataset}"):
          # Extract document text
          print(f"~~~~~~>>>  question: {row.get('question', '')}")
          doc_text = row.get('documents', '')

          # Skip if no documents found
          if not doc_text:
              continue

          # Process the document
          processed_output = process_document_with_identifiers(doc_text)
          added_item_idxs = set()

          # Populate the lists
          for section_idx, section in enumerate(processed_output):
              for item_idx, (prefix, content) in enumerate(section):
                  # Skip if this item_idx has already been processed
                  if item_idx in added_item_idxs:
                      continue

                  # Add the item_idx to the set to track it
                  added_item_idxs.add(item_idx)

                  # Add the document
                  document = f"[{prefix}] {content}"
                  all_documents.append(document)

                  # Construct a globally unique ID
                  doc_id = f"{dataset}_{doc_idx}_{section_idx}_{item_idx}"
                  all_ids.append(doc_id)

                  # Construct metadata
                  metadata = {
                      "dataset": dataset,
                      "global_index": doc_idx,
                      "section_index": section_idx,
                      "item_index": item_idx,
                      "prefix": prefix,
                      "type": "Title" if prefix.endswith("a") else "Passage",
                  }
                  all_metadatas.append(metadata)

          doc_idx += 1  # Increment global document index

  # Step 4: Generate Embeddings
  embedder = SentenceTransformer(embedding_model)  # Pretrained sentence transformer
  batch_size = 2500  # Adjust based on available memory

  # Generate embeddings in batches
  all_embeddings = []
  for i in tqdm(range(0, len(all_documents), batch_size), desc="Generating embeddings"):
      batch_docs = all_documents[i:i + batch_size]
      batch_embeddings = embedder.encode(batch_docs, show_progress_bar=True)
      all_embeddings.extend(batch_embeddings)

  bm25_encoder = prepare_bm25_encoder(all_documents)
  sparse_vectors = [generate_sparse_vector_bm25(text, bm25_encoder) for text in all_documents]

  # Adding data to milvus with enhanced duplicate check
  all_recs = datastor.get_all_records(milvus_collection_name)
  #print(f"sample: {str(all_recs[0])}")
  existing_hashes = get_existing_hashes_milvus(all_recs)

  for i in tqdm(range(0, len(all_documents), batch_size), desc="Adding data to DB"):
      batch_embeddings = all_embeddings[i:i + batch_size]
      batch_sparse_embs = sparse_vectors[i:i + batch_size]
      batch_metadatas = all_metadatas[i:i + batch_size]
      batch_documents = all_documents[i:i + batch_size]
      batch_ids = []

      # Generate hashes for each document in the batch
      for doc, metadata in zip(batch_documents, batch_metadatas):
          doc_hash = generate_hash(doc, metadata)
          if doc_hash not in existing_hashes:
              batch_ids.append(doc_hash)
              existing_hashes.add(doc_hash)  # Add hash to local set to avoid duplicates in the same batch
          else:
              print(f"Skipping duplicate document: {doc[:15]}...")  # Print a preview of the duplicate doc

      # Add non-duplicate documents to the database
      if batch_ids:  # Ensure there are non-duplicate documents to add
          # Add the batch to the Milvus collection
          if store_client == "Milvus" and insert_data:
              datastor.insert(milvus_collection_name,
                  metadata=batch_metadatas,
                  documents=batch_documents,
                  sparse_embs = np.array(batch_sparse_embs),
                  embeddings=np.array(batch_embeddings),
                  ids=batch_ids
              )

  print(f"total data inserted into {milvus_collection_name} iteration {i}")
  print(f"records : {datastor.has_entities(milvus_collection_name)} ")

# %% [markdown]
# #**Retrieval part**

# %% [markdown]
# ## retrieval function declarations

# %%
import torch
import pandas as pd
import langchain
import random
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from transformers import AutoTokenizer, AutoModelForSequenceClassification

def get_api_key():
  # api_keys = ['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', # jay
  #           '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',   # venkat
  #           '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']   # prakash
  # return random.choice(api_keys)
  return "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"

def get_pseudo_doc_embeddings(answer: str):
    chunks = chunk_with_token_limit(answer, TOKEN_LIMIT, SLIDING_WINDOW_OVERLAP)
    return embedder.encode(chunks).tolist()

def fetch_docs_pseudo(query: str):
    answer = generate_pseudo_document_llm(query)
    pseudo_doc_embeddings = get_pseudo_doc_embeddings(answer)
    return datastor.extract_documents(datastor.search(pseudo_doc_embeddings, milvus_collection_name))


# Function to retrieve relevant chunks
def retrieve_docs_milvus(question, collection_name, top_k=10, hybrid=False, hyde=False):
    # Generate embedding for the query
    # Generate the dense embedding for the question
    start_time = time.time()
    dense_query_embedding = embedder.encode(question).tolist()

    # Perform vector search to find relevant chunks
    print(f"{collection_name} has {datastor.has_entities(collection_name)} records")

    if not hybrid:
      results = datastor.search(dense_query_embedding, "ragbench_collection_all_baai_v1", top_k)
      print(f"results: search >>>  {results} from {collection_name}")

    if hybrid:
      # Generate the sparse embedding for the question
      all_records = fetch_complete_docs(
          datastor.extract_docs(
              datastor.get_all_records(milvus_collection_name)))
      bm25_encoder = prepare_bm25_encoder(extract_text(all_records))
      sparse_query_embedding = generate_sparse_vector_bm25(question, bm25_encoder)
      results = datastor.hybrid_search(sparse_query_embedding, dense_query_embedding, milvus_collection_name, top_k)
      print(f"results: hybrid_search >>>  {results} from {collection_name}")

    # HyDE search with pseudo document
    if hyde:
      pseudo_docs = fetch_docs_pseudo(query)
      results.extend(pseudo_docs)
      print(f"pseudo_docs: retrieve_docs_milvus >>>  {len(pseudo_docs)}")

    end_time = time.time()
    print(f"Hybrid Search completed. Found {len(results)} results (approx. 2 * {top_k} + alpha * {top_k}). in {end_time - start_time} secs")
    # Print the extracted documents
    print("retrieve_docs_milvus >>> documents_list from Hybrid + HyDE search >>>>", documents_list)

    # sort the documents in case of hybrid or hyde document retrieval
    if hybrid or hyde:
      documents_list = rerank_with_cross_encoder(question, results)


    return documents_list

# Load Cross-Encoder model and tokenizer
cross_encoder_model_name = "cross-encoder/ms-marco-MiniLM-L-6-v2"
tokenizer = AutoTokenizer.from_pretrained(cross_encoder_model_name)
model = AutoModelForSequenceClassification.from_pretrained(cross_encoder_model_name)

# Ensure PyTorch is in evaluation mode
model.eval()

def rerank_with_cross_encoder(question, results):
    """
    Rerank documents based on relevance scores from a Cross-Encoder model.

    Args:
        query (str): The query string.
        documents (list): A list of document strings.

    Returns:
        list: A list of tuples (document, score), sorted by score in descending order.
    """
    query_embedding = embedder.encode(question)
    # results = datastor.search(query_embedding, collection_name, 5)
    # results = datastor.hybrid(query_embedding, collection_name, 10)
    # documents = datastor.extract_documents(results)

    scores = []
    for doc in documents:
        # Tokenize query-document pair
        inputs = tokenizer(
            question,
            doc,
            return_tensors="pt",
            max_length=512,  # Limit for most transformer models
            truncation=True,
            padding="max_length",
        )
        # Compute relevance scores
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits

            # Handle binary classification or regression logits
            if logits.size(1) == 2:  # Binary classification
                score = torch.softmax(logits, dim=1)[:, 1].item()  # Probability of relevance (class 1)
            else:  # Regression or single-class output
                score = logits.squeeze().item()  # Direct score (e.g., relevance regression)

            scores.append((doc, score))
    # Sort by score in descending order
    return sorted(scores, key=lambda x: x[1], reverse=True)

def query_response_from_llm(query: str, collection_name, model_name="llama3-8b-8192"):

    # retrieve chunks from milvus db
    chunks = retrieve_docs_milvus(query, collection_name)

    if not chunks:
        return "No relevant documents found.", ""

    # retrieve chunks from chroma db
    #chunks = retrieve_docs(query)

    # Flatten the list if necessary
    if any(isinstance(chunk, list) for chunk in chunks):
      chunks = [item for sublist in chunks for item in (sublist if isinstance(sublist, list) else [sublist])]

    chat = ChatGroq(temperature=0.3, groq_api_key=get_api_key(), model_name=model_name)
    # chat = ChatGroq(temperature=0.3, groq_api_key="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", model_name=model_name)

    prompt=ChatPromptTemplate.from_template(
      """
      Please provide a response to the query below, strictly adhering to the
      information presented in the following documents.
      Do not generate any text beyond what is explicitly stated in the documents.

      Context: {context}

      Question: {query}

      Answer:
      """
    )


    chain = prompt | chat

    context = "".join(chunks)

    print("context>>>from 1st RAG>>>>>> ",context)

    groq_response = chain.invoke({"context": context, "query": query})

    print("groq_response>>>from 1st RAG>>>>>> ",groq_response.content)

    answer = groq_response.content
    return answer, context

def generate_prompt():
    """
    Generate a prompt template for assessing the support and relevance of an LLM-generated response.
    """
    return """
    I asked someone to answer a question based on one or more documents.
    Your task is to review their response and assess whether or not each sentence
    in that response is supported by text in the documents. And if so, which
    sentences in the documents provide that support. You will also tell me which
    of the documents contain useful information for answering the question, and
    which of the documents the answer was sourced from.
    Here are the documents, each of which is split into sentences.Alongside each
    sentence is associated key, such as ’[0a].’ or ’[0b].’ that you can use to refer
    to it:

    ‘‘‘
    {documents}
    ‘‘‘
    The question was:
    ‘‘‘
    {question}
    ‘‘‘

    Here is their response, split into sentences. Alongside each sentence is
    associated key, such as ’a.’ or ’b.’ that you can use to refer to it. Note
    that these keys are unique to the response, and are not related to the keys
    in the documents:
    ‘‘‘
    {answer}
    ‘‘‘
    You must respond with a JSON object matching this schema:
    ‘‘‘
    {{
    "relevance_explanation": string,
    "all_relevant_sentence_keys": [string],
    "overall_supported_explanation": string,
    "overall_supported": boolean,
    "sentence_support_information": [
    {{
    "response_sentence_key": string,
    "explanation": string,
    "supporting_sentence_keys": [string],
    "fully_supported": boolean
    }},
    ],
    "all_utilized_sentence_keys": [string]
    }}
    ‘‘‘
    The relevance_explanation field is a string explaining which documents
    contain useful information for answering the question. Provide a step-by-step
    breakdown of information provided in the documents and how it is useful for
    answering the question.
    The all_relevant_sentence_keys field is a list of all document sentences keys
    (e.g. ’0a’) that are relevant to the question. Include every sentence that is
    useful and relevant to the question, even if it was not used in the response,
    or if only parts of the sentence are useful. Ignore the provided response when
    making this judgement and base your judgement solely on the provided documents
    and question. Omit sentences that, if removed from the document, would not
    impact someone’s ability to answer the question.
    The overall_supported_explanation field is a string explaining why the response
    *as a whole* is or is not supported by the documents. In this field, provide a
    step-by-step breakdown of the claims made in the response and the support (or
    lack thereof) for those claims in the documents. Begin by assessing each claim
    separately, one by one; don’t make any remarks about the response as a whole
    until you have assessed all the claims in isolation.
    The overall_supported field is a boolean indicating whether the response as a
    whole is supported by the documents. This value should reflect the conclusion
    you drew at the end of your step-by-step breakdown in overall_supported_explanation.
    In the sentence_support_information field, provide information about the support
    *for each sentence* in the response.
    The sentence_support_information field is a list of objects, one for each sentence
    in the response. Each object MUST have the following fields:
    - response_sentence_key: a string identifying the sentence in the response.
    This key is the same as the one used in the response above.

    - explanation: a string explaining why the sentence is or is not supported by the
    documents.
    - supporting_sentence_keys: keys (e.g. ’[0a]’) of sentences from the documents that
    support the response sentence. If the sentence is not supported, this list MUST
    be empty. If the sentence is supported, this list MUST contain one or more keys.
    In special cases where the sentence is supported, but not by any specific sentence,
    you can use the string "supported_without_sentence" to indicate that the sentence
    is generally supported by the documents. Consider cases where the sentence is
    expressing inability to answer the question due to lack of relevant information in
    the provided context as "supported_without_sentence". In cases where the sentence
    is making a general statement (e.g. outlining the steps to produce an answer, or
    summarizing previously stated sentences, or a transition sentence), use the
    string "general". In cases where the sentence is correctly stating a well-known fact,
    like a mathematical formula, use the string "well_known_fact". In cases where the
    sentence is performing numerical reasoning (e.g. addition, multiplication), use
    the string "numerical_reasoning".
    - fully_supported: a boolean indicating whether the sentence is fully supported by
    the documents.
    - This value should reflect the conclusion you drew at the end of your step-by-step
    breakdown in explanation.
    - If supporting_sentence_keys is an empty list, then fully_supported must be false.
    - Otherwise, use fully_supported to clarify whether everything in the response
    sentence is fully supported by the document text indicated in supporting_sentence_keys
    (fully_supported = true), or whether the sentence is only partially or incompletely
    supported by that document text (fully_supported = false).
    The all_utilized_sentence_keys field is a list of all sentences keys (e.g. ’0a’) that
    were used to construct the answer. Include every sentence that either directly supported
    the answer, or was implicitly used to construct the answer, even if it was not used
    in its entirety. Omit sentences that were not used, and could have been removed from
    the documents without affecting the answer.
    You must respond with a valid JSON string. Use escapes for quotes, e.g. \\"\\", and
    newlines, e.g. \\n. Do not write anything before or after the JSON string. Do not
    wrap the JSON string in backticks like ‘‘‘ or ‘‘‘json.
    As a reminder: your task is to review the response and assess which documents contain
    useful information pertaining to the question, and how each sentence in the response
    is supported by the text in the documents.
    """.strip()

def analyze_llm_response(question, context, answer):
  chat = ChatGroq(temperature=0.3, groq_api_key=get_api_key(), model_name="llama3-70b-8192")
  # chat = ChatGroq(temperature=0.3, groq_api_key="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", model_name="llama3-70b-8192")

  prompt_template_with_docs = PromptTemplate(
      input_variables=["documents", "question", "answer"],
      template=generate_prompt(),
  )

  chain = prompt_template_with_docs | chat
  groq_response_with_context_qanda = chain.invoke({"documents": context, "question": question, "answer":answer})
  return groq_response_with_context_qanda

# %%
import re
from sklearn.metrics import mean_squared_error, roc_auc_score
import numpy as np
from sklearn.metrics import roc_auc_score
from datasets import load_dataset
from datasets import concatenate_datasets

# Helper function for length computation (mocked as sentence count here)
def compute_length(keys):
    return len(keys)

# Metrics Computation
def compute_metrics(data):
    all_relevant = data["all_relevant_sentence_keys"]
    all_utilized = data["all_utilized_sentence_keys"]
    sentences_info = data["sentence_support_information"]

    # Context Relevance
    total_relevant_length = compute_length(all_relevant)
    total_context_length = total_relevant_length  # Assuming all relevant are part of the context
    context_relevance = total_relevant_length / total_context_length if total_context_length > 0 else 0

    # Context Utilization
    total_utilized_length = compute_length(all_utilized)
    context_utilization = total_utilized_length / total_context_length if total_context_length > 0 else 0

    # Completeness
    total_relevant_utilized = sum(
        1 for s in sentences_info if set(s["supporting_sentence_keys"]).intersection(all_utilized)
    )
    completeness = total_relevant_utilized / total_relevant_length if total_relevant_length > 0 else 0

    # Adherence
    adherence = data['overall_supported']

    return {
        "Context Relevance": context_relevance,
        "Context Utilization": context_utilization,
        "Completeness": completeness,
        "Adherence": adherence
    }


# Compute and print metrics
def fetch_ground_truth(dataset_name, question):
    dataset_dict = load_dataset("rungalileo/ragbench", dataset_name)
    dataset = concatenate_datasets([ds for ds in dataset_dict.values()])  # Combine all splits

    for sample in dataset:  # Iterate over the concatenated dataset
        if sample["question"] == question:
            return {
                "Context Relevance": sample.get("relevance_score"),  # Use .get() to avoid KeyErrors
                "Context Utilization": sample.get("utilization_score"),
                "Adherence": sample.get("adherence_score")
            }
    return None  # Ensure None is returned only if no match is found


def compute_rmse(predicted, ground_truth):
    # Extract true and predicted values
    y_true_relevance = ground_truth["Context Relevance"]
    y_true_utilization = ground_truth["Context Utilization"]

    y_pred_relevance = predicted["Context Relevance"]
    y_pred_utilization = predicted["Context Utilization"]

    # Compute RMSE for Context Relevance and Context Utilization
    rmse_relevance = np.sqrt((y_pred_relevance - y_true_relevance) ** 2)
    rmse_utilization = np.sqrt((y_pred_utilization - y_true_utilization) ** 2)

    return {
        "RMSE-Relevance": rmse_relevance,
        "RMSE-Utililization": rmse_utilization,
        "Adherence_ground": ground_truth["Adherence"],
        "Adherence_pred": predicted['Adherence'],
    }


def compute_auc_roc(predicted_adherence, ground_truth_adherence):
    # Handle boolean values directly
    y_true_numeric_alt = [1 if item else 0 for item in ground_truth_adherence]
    y_pred_numeric_alt = [1 if item else 0 for item in predicted_adherence]

    # Compute AUC-ROC
    auc_roc = roc_auc_score(y_true_numeric_alt, y_pred_numeric_alt)
    return auc_roc

def compute_metrics_rmse_roc(data, dataset_name, question):
    predicted_metrics = compute_metrics(data)
    print(f"query >>>> {question}")
    print(f"dataset_name >>>> {dataset_name}")
    ground_truth = fetch_ground_truth(dataset_name, question)
    print(f"ground truth {json.dumps(ground_truth)}")
    print(f"predict truth {json.dumps(predicted_metrics)}")

    rmse_values = compute_rmse(predicted_metrics, ground_truth)
    auc_roc = None
    if ground_truth:
      ground_truth_adherence = ground_truth['Adherence']
      predicted_adherence = predicted_metrics["Adherence"]

    return {
        "RMSE-Relevance": rmse_values["RMSE-Relevance"],
        "RMSE-Utililization": rmse_values["RMSE-Utililization"],
        "Adherence_ground": ground_truth_adherence,
        "Adherence_pred": predicted_adherence,
    }

# %%
# Added for testing the fix for fetch_ground_truth. Remove after testing

from datasets import load_dataset
from datasets import concatenate_datasets
import json
# Compute and print metrics
def fetch_ground_truth(dataset_name, question):
    dataset_dict = load_dataset("rungalileo/ragbench", dataset_name, split=None)
    dataset = concatenate_datasets([ds for ds in dataset_dict.values()])  # Combine all splits

    for sample in dataset:  # Iterate over the concatenated dataset
        if sample["question"] == question:
            return {
                "Context Relevance": sample.get("relevance_score"),  # Use .get() to avoid KeyErrors
                "Context Utilization": sample.get("utilization_score"),
                "Adherence": sample.get("adherence_score")
            }
    return None  # Ensure None is returned only if no match is found

question = "What have sero-surveys of MERS virus found?"
ground_truth = fetch_ground_truth("covidqa", question)
print(f"ground truth {json.dumps(ground_truth)}")
# Out:
# README.md:   0%|          | 0.00/24.7k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/4.20M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/854k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/913k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1252 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/246 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/267 [00:00<?, ? examples/s]
# ground truth {"Context Relevance": 0.17391304347826086, "Context Utilization": 0.13043478260869565, "Adherence": false}

# %% [markdown]
# **The below cell is for generating metrics only**

# %%
import json

# Placeholder function to get response from your LLM/RAG pipeline
def get_response_for_metrics(query, model_name, rag_bench):
    collection_name = f"ragbench_collection_{rag_bench}"
    # collection_name = "ragbench_collection_all_baai_v1"
    print(f"Response from {collection_name} for query: {query}")  # Replace with actual model call
    answer, context = query_response_from_llm(query, collection_name, model_name)
    if not context:
      return answer, "unable to generate stats from llm"
    response = analyze_llm_response(query, context, answer)
    data = json.loads(response.content)
    predict_metrics = compute_metrics(data)
    ground_truth = fetch_ground_truth(rag_bench, query)
    if not ground_truth:
      return answer, None
    analytics = compute_rmse(predict_metrics, ground_truth)
    stats = {"data": data, "analytics": analytics}
    return answer, analytics

# %%
llm_models = ["llama3-8b-8192", "deepseek-r1-distill-llama-70b"]  # Modify as needed

# rag_banch_datasets = ['covidqa','cuad','delucionqa','emanual','expertqa',
#                       'finqa','hagrid','hotpotqa','msmarco','pubmedqa','tatqa','techqa']


rag_banch_datasets = ['covidqa']

#data = load_dataset("rungalileo/ragbench", rag_banch_datasets[0], split="train")
# collection_name = "ragbench_collection_all_baai_v1"
n = 100
counter = 0;
rmse_util = 0
rmse_rel = 0
adherence_ground = []
adherence_pred = []

for dataset in rag_banch_datasets:
  print(f"dataset >>>> {dataset}")
  data = load_dataset("rungalileo/ragbench", dataset, split="train")
  top_n_rows = data.select(range(n))
  for i, row in enumerate(top_n_rows):
    question = row['question']

    try:
      res_answer, res_stats = get_response_for_metrics(question, llm_models[0], dataset)
      print("res_stats<<<",res_stats)
      if not res_stats:
        continue
      rmse_rel += res_stats['RMSE-Relevance']
      rmse_util += res_stats['RMSE-Utililization']
      adherence_ground.append(res_stats['Adherence_ground'])
      adherence_pred.append(res_stats['Adherence_pred'])
      counter += 1

    except json.JSONDecodeError as e:
      print(f"JSON decoding failed: {e}")
    except Exception as e:
      print(f"An error occurred: {e}")

    continue

  time.sleep(5)

  auc_roc = compute_auc_roc(adherence_pred, adherence_ground)
  avg_rmse_util = rmse_util/counter
  avg_rmse_rel = rmse_rel/counter

  print(f"Final result to copy ~~~~~~~~~~~~~~~~~~~ RAGBENCH >>>>>> {dataset} >>> average rmse utilization:  {avg_rmse_util}")
  print(f"Final result to copy ~~~~~~~~~~~~~~~~~~~ RAGBENCH >>>>>> {dataset} >>> average rmse relevance:  {avg_rmse_rel}")
  print(f"Final result to copy ~~~~~~~~~~~~~~~~~~~ RAGBENCH >>>>>> {dataset} >>> auc roc value: {auc_roc}")

  #reset all values for next dataset
  rmse_util = 0
  rmse_rel = 0
  adherence_ground = []
  adherence_pred = []
  time.sleep(5)
# Out:
# dataset >>>> covidqa
# Response from ragbench_collection_covidqa for query: What role does T-cell count play in severe human adenovirus type 55 (HAdV-55) infection?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009438991546630859 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1335148811340332 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is MVO?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009899139404296875 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08215618133544922 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What have sero-surveys of MERS virus found?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009009838104248047 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.0982670783996582 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How were untreated MDA-MB-231 cells labeled?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0010247230529785156 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11532449722290039 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the number of inhabitants of Reunion Island?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009024143218994141 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09393453598022461 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What genome sequence was available for this study?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009205341339111328 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08718180656433105 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is  the destabilization is further compounded by?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0011413097381591797 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10556960105895996 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How many amino acids are in the SARS-CoV E protein?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0010867118835449219 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10519075393676758 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the  the rate of general transmission, even in outbreaks?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009493827819824219 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09945321083068848 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What primer pairs were used for PCR?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009036064147949219 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.0912485122680664 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What are the most revealing signs that SARS-CoV-2 evolved by natural evolution.
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009706020355224609 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1156768798828125 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What COVs were known to infect humans before December 2019?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0008819103240966797 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09864473342895508 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Where else MERS-COV has also been detected?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.001026153564453125 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10521268844604492 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What testing and detection are needed?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009167194366455078 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08379769325256348 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How does the transmissibility of 2019-nCOV compare with other viruses?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009932518005371094 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.12320327758789062 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What were the common HCOV strains in the 5 year USA study?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.001089334487915039 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10377120971679688 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What do neuroaminidase inhibitors target?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0010433197021484375 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09898948669433594 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What was the purpose of this study?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009133815765380859 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08492565155029297 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What do those abnormalities sometimes culminate in?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009243488311767578 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.0896153450012207 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the amino acid similarity between IFITM5 and the other IFITM proteins?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009675025939941406 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11758184432983398 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What are the conclusions of this study?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009202957153320312 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08536887168884277 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How many clinical trials are registered?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009477138519287109 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.0870058536529541 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What happened to the case who died?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009779930114746094 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09164214134216309 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What are the most common viruses?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0010077953338623047 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08773112297058105 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What  effect the use of steroids to  suppress inflammation can have?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.000986337661743164 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.12052655220031738 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How much  is the reduction in the childhood pneumonia deaths?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.001005411148071289 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09584546089172363 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Which  four studies were included?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009143352508544922 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08942937850952148 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What type of vaccine is used to protect against FIPV infection?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009696483612060547 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10559391975402832 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What are examples of  viral vectors for delivering vaccines?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009686946868896484 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09075498580932617 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How long human urine and stool have been found to contain MERS-CoV RNA?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.001397848129272461 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11833953857421875 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What types of cells follow epithelial cells in the immune response to infections in the lung?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009489059448242188 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11850976943969727 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is R0?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0021142959594726562 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08247542381286621 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Why is the determination of asymptomatic or pre-symptomatic transmission, an urgent priority?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0010142326354980469 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.12837481498718262 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is Chikungunya virus?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009369850158691406 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09020161628723145 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What diagnostic test is correlated with the severity of HFRS?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.00090789794921875 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11543965339660645 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is a function associated with IFITM5?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0010178089141845703 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10104823112487793 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What the animal vector reservoir for Hantaan virus?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0008776187896728516 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09559059143066406 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Where do the respiratory viruses primarily infect and replicate?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009295940399169922 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.0950319766998291 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: When did Hantavirus infections became a concern in the Americas?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009706020355224609 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10019779205322266 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: When does the camel calving season?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009455680847167969 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09006261825561523 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What are the most frequent clinical manifestations of human adenovirus type 55 (HAdV-55) induced ARDS?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009958744049072266 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1337575912475586 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Why is the phage ab excellent model system for directed protein evolution?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0011208057403564453 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10432982444763184 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the ongoing randomized trial investigating?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009777545928955078 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09167361259460449 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What was the most common virus detected in community samples in Ilorin, Nigeria?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.000957489013671875 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10929083824157715 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How safe is NYVAC?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009646415710449219 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.0989675521850586 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What was the failure of rAd5 vaccine for inducing HIV-1 specific T cell response?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0011019706726074219 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11902236938476562 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How long did it take to publish the full genomic sequence of SARS-CoV-2 after it was identified?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009262561798095703 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1307392120361328 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What can happen  in response to the infection such as neutrophils?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009770393371582031 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11313390731811523 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What nucleoside analog is the focus of the current study?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009293556213378906 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10433459281921387 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What do the S1 and S2 subunits of spike glycoprotein contain?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0010972023010253906 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11689996719360352 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Which Lactobacililus casei strain does not have the cholera toxin subunit A1 (CTA1) on the surface?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009329319000244141 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.13144850730895996 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What's the recommended method to disinfect floors for COVID-19?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.00861978530883789 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.12278008460998535 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: When did China introduce strict movement restrictions and other measures including case isolation and quarantine?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009076595306396484 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.16099047660827637 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the cause of Feline Infectious Peritonitis (FIP)?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0010066032409667969 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1193230152130127 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What did the finding prompt ECDC to do?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009021759033203125 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09163451194763184 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the population-averaged infection fatality ratio?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009336471557617188 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09398293495178223 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the premise for apathogenic forms to  blunt any pathological response in the host?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009427070617675781 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11559009552001953 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What was attributed to the spread of SARS-COV at Amoy Gardens?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009369850158691406 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11275148391723633 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What should mildly-ill patients do?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009427070617675781 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08495759963989258 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the advantage of the VEE replicon system?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009715557098388672 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10153460502624512 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What  does the analysis show on the difference between locally acquired cases vs imported cases?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0008928775787353516 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10658526420593262 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the effect of Glycyrrhizin in viral infections?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009627342224121094 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1106410026550293 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How long is the SAIBK gene?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0010228157043457031 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.09935450553894043 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What enzymes have been reported to be linked with severity of infection and various pathological conditions caused by microorganisms?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009794235229492188 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.13822555541992188 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the foremost authority on minimum standards for humanitarian assistance?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009474754333496094 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10091447830200195 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is  NPA?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009207725524902344 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08041000366210938 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Which group of RNA quasispecies satisfy criteria for life?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009369850158691406 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.10486531257629395 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What makes filamentous phage ideal scaffold for bioconjugation?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009443759918212891 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.11498188972473145 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is mobile  population in Wuhan?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0018002986907958984 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08626580238342285 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What serious question was raised?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009264945983886719 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.08595967292785645 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the incubation period of MERS?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009300708770751953 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.0970456600189209 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What does the microscopic examination of the lung reveal, as with human HCPS?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0013649463653564453 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1213676929473877 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the function of neuroaminidase in the influenza virus?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0010900497436523438 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.17088055610656738 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is one of  the major sources of exacerbation of chronic airway inflammatory diseases?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0016357898712158203 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.19125747680664062 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Which is the source animal for the MERS-COV?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.001299142837524414 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1471729278564453 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What are some non-pharmaceutical interventions?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0014560222625732422 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.12390661239624023 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: When did the White House launch the "15 Days to Slow the Spread" program?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0011472702026367188 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1634209156036377 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the most common subgroup of HMPV?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0013916492462158203 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1511847972869873 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Why do low levels of DC-SIGNR enhance Mother to Child Transmission of HIV-1?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0014698505401611328 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.18238329887390137 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What proportion of healthcare workers reported symptoms of anxiety?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0011267662048339844 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.12905406951904297 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Which medical comorbidities most profoundly influenced MERS-CoV outcomes?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0014181137084960938 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.16037225723266602 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Which bacteial delivery vectors have gained favor for vaccines?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0014011859893798828 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.16187071800231934 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What  is the FPA optimization algorithm inspired by?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0018243789672851562 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.14175701141357422 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Why is it likely that MA15 is highly attenuated to  replicate in human cells?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0012972354888916016 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.17870664596557617 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Respiratory viral pathogens were present in what percentage of samples?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0013966560363769531 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.15105175971984863 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Who was excluded from the study?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0014946460723876953 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.13341212272644043 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: Has AAV been studied as  vectors for influenza?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0012843608856201172 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.13295412063598633 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What other tests should be considered for 2019-nCOV epidemiology?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0013339519500732422 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1625373363494873 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What other viruses are implicated in acute exacerbations but to a much lesser extent?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0012056827545166016 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.16997194290161133 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What kind of pertussis vaccine is used in middle and high income countries?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0012111663818359375 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.15507102012634277 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How does the proposed FPASSA start?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.001322031021118164 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.12488126754760742 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What age group has the highest rate of severe outcomes?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0013968944549560547 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1492137908935547 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How long MERS-CoV remained viable at high ambient temperature (30°C) and low RH (30 %) ?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0013239383697509766 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.22725868225097656 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How were  the spread of GFP-expressing virus-infected cells across tissue monolayers tracked via inverted fluorescence microscopy?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0012562274932861328 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.19783520698547363 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is the conclusion of  this report?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.001447916030883789 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.12256550788879395 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is a key factor in managing emerging infectious disease threats?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0012292861938476562 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.14896035194396973 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How does transmission differ between SARS-CoV and MERS-CoV?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0009622573852539062 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.17728734016418457 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What leads to oxidative stress in the body?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0012500286102294922 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.15305495262145996 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: What is theorized regarding transmission?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0016636848449707031 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.13414669036865234 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# Response from ragbench_collection_covidqa for query: How can DNA arise chemically from RNA?
# ragbench_collection_covidqa has 57 records
# Search completed. Found 0 results. in 0.0014796257019042969 secs
# results: search >>>  [] from ragbench_collection_covidqa
# Hybrid Search completed. Found 0 results (approx. 2 * 10 + alpha * 10). in 0.1403045654296875 secs
# An error occurred: cannot access local variable 'documents_list' where it is not associated with a value
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-66d49e8b75aa> in <cell line: 0>()
#      43   time.sleep(5)
#      44
# ---> 45   auc_roc = compute_auc_roc(adherence_pred, adherence_ground)
#      46   avg_rmse_util = rmse_util/counter
#      47   avg_rmse_rel = rmse_rel/counter
#
# <ipython-input-10-32926e1fee4f> in compute_auc_roc(predicted_adherence, ground_truth_adherence)
#      83
#      84     # Compute AUC-ROC
# ---> 85     auc_roc = roc_auc_score(y_true_numeric_alt, y_pred_numeric_alt)
#      86     return auc_roc
#      87
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     617
#     618     y_type = type_of_target(y_true, input_name="y_true")
# --> 619     y_true = check_array(y_true, ensure_2d=False, dtype=None)
#     620     y_score = check_array(y_score, ensure_2d=False)
#     621
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1128         n_samples = _num_samples(array)
#    1129         if n_samples < ensure_min_samples:
# -> 1130             raise ValueError(
#    1131                 "Found array with %d sample(s) (shape=%s) while a"
#    1132                 " minimum of %d is required%s."
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
import json

# Correcting how the JSON is assigned as a string
json_data = '''{
    "data": {
        "relevance_explanation": "The documents contain information about HAdV-55 infection, but none of them explicitly mention the role of T-cell count in severe HAdV-55 infection. However, document [0a] mentions CD4+ T Lymphocytes in the context of co-infection with HTLV-1 and HIV, which might be relevant to the question.",
        "all_relevant_sentence_keys": [
            "[0a]",
            "[0b]"
        ],
        "overall_supported_explanation": "The response claims that there is no information provided in the given documents about the role of T-cell count in severe human adenovirus type 55 (HAdV-55) infection. This claim is supported by the documents, as none of them explicitly mention the role of T-cell count in HAdV-55 infection.",
        "overall_supported": true,
        "sentence_support_information": [
            {
                "response_sentence_key": "a.",
                "explanation": "The sentence is supported by the lack of information in the documents about the role of T-cell count in severe HAdV-55 infection.",
                "supporting_sentence_keys": [],
                "fully_supported": true
            }
        ],
        "all_utilized_sentence_keys": []
    },
    "analytics_json": {
        "RMSE-Relevance": 0.6842105263157895,
        "RMSE-Utililization": 0.3157894736842105
    }
}'''

# Load JSON data
data = json.loads(json_data)

# Access 'overall_supported' value
overall_supported = data['data']['overall_supported']

print(overall_supported)
# Out:
# True

# %% [markdown]
# ## **Setup function for Gradio**

# %%
import json

# Placeholder function to get response from your LLM/RAG pipeline
def get_response(query, model_name, rag_bench):
    collection_name = f"ragbench_collection_{rag_bench}"
    print(f"Response from {collection_name} for query: {query}")  # Replace with actual model call
    answer, context = query_response_from_llm(query, collection_name, model_name)
    if not context:
      return answer, "unable to generate stats from llm"
    response = analyze_llm_response(query, context, answer)
    data = json.loads(response.content)
    predict_metrics = compute_metrics(data)
    ground_truth = fetch_ground_truth(rag_bench, query)
    if not ground_truth:
      return answer, "" + json.dumps(data, indent=4) + "```"
    analytics_json = compute_rmse(predict_metrics, ground_truth)
    stats = "```" + json.dumps({"data": data, "analytics_json": analytics_json}, indent=4) + "```"
    return answer, stats

# %%
answer, resp = get_response("What have sero-surveys of MERS virus found?", "llama3-8b-8192", 'covidqa')
print(answer)
print(resp)
# Out:
# Response from ragbench_collection_covidqa for query: What have sero-surveys of MERS virus found?
# ragbench_collection_covidqa has 57 records
# search results size : 1
# Collection: ragbench_collection_covidqa, data: {'id': '68c0015df08449fcd270c34d2455994b', 'distance': 0.9065372347831726, 'entity': {'documents': '[0a] Title: MERS coronavirus: diagnostics, epidemiology and transmission\nPassage: for human sero-surveys.', 'metadata': {'dataset': 'covidqa', 'global_index': 2, 'section_index': 0, 'item_index': 0, 'prefix': '0a', 'type': 'Title'}}}
# Collection: ragbench_collection_covidqa, data: {'id': 'fb017e0b19894d6f7996613624e91541', 'distance': 0.8914117217063904, 'entity': {'documents': '[0b] No sign of MERS-CoV antibodies was found among 2,400 sera from patients visiting Hospital in Jeddah, from 2010 through 2012, prior to the description of MERS-CoV .', 'metadata': {'dataset': 'covidqa', 'global_index': 2, 'section_index': 0, 'item_index': 2, 'prefix': '0b', 'type': 'Passage'}}}
# Collection: ragbench_collection_covidqa, data: {'id': '464288cb0f98dcb4891aaab5b92385e4', 'distance': 0.8765860795974731, 'entity': {'documents': '[0c] Nor did IFA methods detect any sign of prior MERS-CoV infection among a small sample of 130 healthy blood donors from another Hospital in Jeddah .', 'metadata': {'dataset': 'covidqa', 'global_index': 2, 'section_index': 0, 'item_index': 3, 'prefix': '0c', 'type': 'Passage'}}}
# Collection: ragbench_collection_covidqa, data: {'id': '01b49146374d9b4c41b8f20e8a41f1cb', 'distance': 0.8703879714012146, 'entity': {'documents': '[0a] These relied on MERS-CoV-infected cell culture as an antigen source, detecting the presence of human anti-MERS-CoV IgG, IgM or neutralizing antibodies in human samples .', 'metadata': {'dataset': 'covidqa', 'global_index': 2, 'section_index': 0, 'item_index': 1, 'prefix': '0a', 'type': 'Title'}}}
# Collection: ragbench_collection_covidqa, data: {'id': '1d9786542d377515d066637e6d921e3a', 'distance': 0.8569615483283997, 'entity': {'documents': '[1b] In fact, the attack rate of pH1N1/2009 infection in our serosurvey was about 42%-44% at the peak of the antibody response , a figure which is at least 3 to 4 times higher than rates', 'metadata': {'dataset': 'covidqa', 'global_index': 4, 'section_index': 1, 'item_index': 2, 'prefix': '1b', 'type': 'Passage'}}}
# Collection: ragbench_collection_covidqa, data: {'id': 'fb84aefe6953c52723a46af4214a25cd', 'distance': 0.8420277833938599, 'entity': {'documents': '[0a] Title: Pandemic Influenza Due to pH1N1/2009 Virus: Estimation of Infection Burden in Reunion Island through a Prospective Serosurvey, Austral Winter 2009\nPassage: the population of Reunion Island and a Chi2 test was used to analyse differences in age, sex and geographic location.', 'metadata': {'dataset': 'covidqa', 'global_index': 4, 'section_index': 0, 'item_index': 0, 'prefix': '0a', 'type': 'Title'}}}
# Collection: ragbench_collection_covidqa, data: {'id': 'a78ba1a233db687b63faff7187805de0', 'distance': 0.8377702236175537, 'entity': {'documents': '[0a] Title: Global Surveillance of Emerging Influenza Virus Genotypes by Mass Spectrometry\nPassage: primer pairs targeting NP and PB2 segments.', 'metadata': {'dataset': 'covidqa', 'global_index': 9, 'section_index': 0, 'item_index': 0, 'prefix': '0a', 'type': 'Title'}}}
# Collection: ragbench_collection_covidqa, data: {'id': 'dabb7ebd2e6a798728346e923384aa6c', 'distance': 0.8220858573913574, 'entity': {'documents': '[0d] The median outbreak size, as measured by the total number of cases, was 4 with a range of 1 to 134', 'metadata': {'dataset': 'covidqa', 'global_index': 8, 'section_index': 0, 'item_index': 4, 'prefix': '0d', 'type': 'Passage'}}}
# Collection: ragbench_collection_covidqa, data: {'id': '725baa8a413a2eede51063e4f6e8a079', 'distance': 0.8168007135391235, 'entity': {'documents': '[0a] Cumulative incidence rates of infection and seroconversion rates were standardized according to the age structure of the community source).', 'metadata': {'dataset': 'covidqa', 'global_index': 4, 'section_index': 0, 'item_index': 1, 'prefix': '0a', 'type': 'Title'}}}
# Collection: ragbench_collection_covidqa, data: {'id': '5ae54b355620abf68a3c0240540b1df4', 'distance': 0.815681517124176, 'entity': {'documents': '[2c] pH1N1/2009v became the predominant circulating influenza virus within four weeks of its first detection, its activity peaked during week 35 and ended at week 38 .', 'metadata': {'dataset': 'covidqa', 'global_index': 4, 'section_index': 2, 'item_index': 3, 'prefix': '2c', 'type': 'Passage'}}}
# Search completed. Found 10 results. in 0.1307070255279541 secs
# results: hybrid_search >>>  [{'collection': 'ragbench_collection_covidqa', 'id': '5ae54b355620abf68a3c0240540b1df4', 'metadata': {'dataset': 'covidqa', 'global_index': 4, 'section_index': 2, 'item_index': 3, 'prefix': '2c', 'type': 'Passage'}, 'distance': 0.815681517124176, 'documents': '[2c] pH1N1/2009v became the predominant circulating influenza virus within four weeks of its first detection, its activity peaked during week 35 and ended at week 38 .'}, {'collection': 'ragbench_collection_covidqa', 'id': '725baa8a413a2eede51063e4f6e8a079', 'metadata': {'dataset': 'covidqa', 'global_index': 4, 'section_index': 0, 'item_index': 1, 'prefix': '0a', 'type': 'Title'}, 'distance': 0.8168007135391235, 'documents': '[0a] Cumulative incidence rates of infection and seroconversion rates were standardized according to the age structure of the community source).'}, {'collection': 'ragbench_collection_covidqa', 'id': 'dabb7ebd2e6a798728346e923384aa6c', 'metadata': {'dataset': 'covidqa', 'global_index': 8, 'section_index': 0, 'item_index': 4, 'prefix': '0d', 'type': 'Passage'}, 'distance': 0.8220858573913574, 'documents': '[0d] The median outbreak size, as measured by the total number of cases, was 4 with a range of 1 to 134'}, {'collection': 'ragbench_collection_covidqa', 'id': 'a78ba1a233db687b63faff7187805de0', 'metadata': {'dataset': 'covidqa', 'global_index': 9, 'section_index': 0, 'item_index': 0, 'prefix': '0a', 'type': 'Title'}, 'distance': 0.8377702236175537, 'documents': '[0a] Title: Global Surveillance of Emerging Influenza Virus Genotypes by Mass Spectrometry\nPassage: primer pairs targeting NP and PB2 segments.'}, {'collection': 'ragbench_collection_covidqa', 'id': 'fb84aefe6953c52723a46af4214a25cd', 'metadata': {'dataset': 'covidqa', 'global_index': 4, 'section_index': 0, 'item_index': 0, 'prefix': '0a', 'type': 'Title'}, 'distance': 0.8420277833938599, 'documents': '[0a] Title: Pandemic Influenza Due to pH1N1/2009 Virus: Estimation of Infection Burden in Reunion Island through a Prospective Serosurvey, Austral Winter 2009\nPassage: the population of Reunion Island and a Chi2 test was used to analyse differences in age, sex and geographic location.'}, {'collection': 'ragbench_collection_covidqa', 'id': '1d9786542d377515d066637e6d921e3a', 'metadata': {'dataset': 'covidqa', 'global_index': 4, 'section_index': 1, 'item_index': 2, 'prefix': '1b', 'type': 'Passage'}, 'distance': 0.8569615483283997, 'documents': '[1b] In fact, the attack rate of pH1N1/2009 infection in our serosurvey was about 42%-44% at the peak of the antibody response , a figure which is at least 3 to 4 times higher than rates'}, {'collection': 'ragbench_collection_covidqa', 'id': '01b49146374d9b4c41b8f20e8a41f1cb', 'metadata': {'dataset': 'covidqa', 'global_index': 2, 'section_index': 0, 'item_index': 1, 'prefix': '0a', 'type': 'Title'}, 'distance': 0.8703879714012146, 'documents': '[0a] These relied on MERS-CoV-infected cell culture as an antigen source, detecting the presence of human anti-MERS-CoV IgG, IgM or neutralizing antibodies in human samples .'}, {'collection': 'ragbench_collection_covidqa', 'id': '464288cb0f98dcb4891aaab5b92385e4', 'metadata': {'dataset': 'covidqa', 'global_index': 2, 'section_index': 0, 'item_index': 3, 'prefix': '0c', 'type': 'Passage'}, 'distance': 0.8765860795974731, 'documents': '[0c] Nor did IFA methods detect any sign of prior MERS-CoV infection among a small sample of 130 healthy blood donors from another Hospital in Jeddah .'}, {'collection': 'ragbench_collection_covidqa', 'id': 'fb017e0b19894d6f7996613624e91541', 'metadata': {'dataset': 'covidqa', 'global_index': 2, 'section_index': 0, 'item_index': 2, 'prefix': '0b', 'type': 'Passage'}, 'distance': 0.8914117217063904, 'documents': '[0b] No sign of MERS-CoV antibodies was found among 2,400 sera from patients visiting Hospital in Jeddah, from 2010 through 2012, prior to the description of MERS-CoV .'}, {'collection': 'ragbench_collection_covidqa', 'id': '68c0015df08449fcd27 ...
# Hybrid Search completed. Found 10 results (approx. 2 * 10 + alpha * 10). in 0.5783431529998779 secs
# retrieve_docs_milvus >>> documents_list from Hybrid + HyDE search >>>> ['[2c] pH1N1/2009v became the predominant circulating influenza virus within four weeks of its first detection, its activity peaked during week 35 and ended at week 38 .', '[0a] Cumulative incidence rates of infection and seroconversion rates were standardized according to the age structure of the community source).', '[0d] The median outbreak size, as measured by the total number of cases, was 4 with a range of 1 to 134', '[0a] Title: Global Surveillance of Emerging Influenza Virus Genotypes by Mass Spectrometry\nPassage: primer pairs targeting NP and PB2 segments.', '[0a] Title: Pandemic Influenza Due to pH1N1/2009 Virus: Estimation of Infection Burden in Reunion Island through a Prospective Serosurvey, Austral Winter 2009\nPassage: the population of Reunion Island and a Chi2 test was used to analyse differences in age, sex and geographic location.', '[1b] In fact, the attack rate of pH1N1/2009 infection in our serosurvey was about 42%-44% at the peak of the antibody response , a figure which is at least 3 to 4 times higher than rates', '[0a] These relied on MERS-CoV-infected cell culture as an antigen source, detecting the presence of human anti-MERS-CoV IgG, IgM or neutralizing antibodies in human samples .', '[0c] Nor did IFA methods detect any sign of prior MERS-CoV infection among a small sample of 130 healthy blood donors from another Hospital in Jeddah .', '[0b] No sign of MERS-CoV antibodies was found among 2,400 sera from patients visiting Hospital in Jeddah, from 2010 through 2012, prior to the description of MERS-CoV .', '[0a] Title: MERS coronavirus: diagnostics, epidemiology and transmission\nPassage: for human sero-surveys.']
# context>>>from 1st RAG>>>>>>  [2c] pH1N1/2009v became the predominant circulating influenza virus within four weeks of its first detection, its activity peaked during week 35 and ended at week 38 .[0a] Cumulative incidence rates of infection and seroconversion rates were standardized according to the age structure of the community source).[0d] The median outbreak size, as measured by the total number of cases, was 4 with a range of 1 to 134[0a] Title: Global Surveillance of Emerging Influenza Virus Genotypes by Mass Spectrometry
# Passage: primer pairs targeting NP and PB2 segments.[0a] Title: Pandemic Influenza Due to pH1N1/2009 Virus: Estimation of Infection Burden in Reunion Island through a Prospective Serosurvey, Austral Winter 2009
# Passage: the population of Reunion Island and a Chi2 test was used to analyse differences in age, sex and geographic location.[1b] In fact, the attack rate of pH1N1/2009 infection in our serosurvey was about 42%-44% at the peak of the antibody response , a figure which is at least 3 to 4 times higher than rates[0a] These relied on MERS-CoV-infected cell culture as an antigen source, detecting the presence of human anti-MERS-CoV IgG, IgM or neutralizing antibodies in human samples .[0c] Nor did IFA methods detect any sign of prior MERS-CoV infection among a small sample of 130 healthy blood donors from another Hospital in Jeddah .[0b] No sign of MERS-CoV antibodies was found among 2,400 sera from patients visiting Hospital in Jeddah, from 2010 through 2012, prior to the description of MERS-CoV .[0a] Title: MERS coronavirus: diagnostics, epidemiology and transmission
# Passage: for human sero-surveys.
# groq_response>>>from 1st RAG>>>>>>  According to the provided documents, sero-surveys of MERS virus have found:
#
# * No sign of prior MERS-CoV infection among a small sample of 130 healthy blood donors from another Hospital in Jeddah.
# * No sign of MERS-CoV antibodies was found among 2,400 sera from patients visiting Hospital in Jeddah, from 2010 through 2012, prior to the description of MERS-CoV.
#
# Note that these findings are based on the passages provided and do not include any information about sero-surveys of pH1N1/2009 virus or other topics.
# According to the provided documents, sero-surveys of MERS virus have found:
#
# * No sign of prior MERS-CoV infection among a small sample of 130 healthy blood donors from another Hospital in Jeddah.
# * No sign of MERS-CoV antibodies was found among 2,400 sera from patients visiting Hospital in Jeddah, from 2010 through 2012, prior to the description of MERS-CoV.
#
# Note that these findings are based on the passages provided and do not include any information about sero-surveys of pH1N1/2009 virus or other topics.
# ```{
#     "data": {
#         "relevance_explanation": "The document with title 'MERS coronavirus: diagnostics, epidemiology and transmission' contains useful information for answering the question about sero-surveys of MERS virus.",
#         "all_relevant_sentence_keys": [
#             "[0c]",
#             "[0b]",
#             "[0a]"
#         ],
#         "overall_supported_explanation": "The response claims that sero-surveys of MERS virus have found no sign of prior MERS-CoV infection among a small sample of 130 healthy blood donors from another Hospital in Jeddah, and no sign of MERS-CoV antibodies was found among 2,400 sera from patients visiting Hospital in Jeddah, from 2010 through 2012, prior to the description of MERS-CoV. These claims are supported by sentences [0c] and [0b] in the document 'MERS coronavirus: diagnostics, epidemiology and transmission'.",
#         "overall_supported": true,
#         "sentence_support_information": [
#             {
#                 "response_sentence_key": "a.",
#                 "explanation": "This sentence is supported by sentence [0c] in the document 'MERS coronavirus: diagnostics, epidemiology and transmission'.",
#                 "supporting_sentence_keys": [
#                     "[0c]"
#                 ],
#                 "fully_supported": true
#             },
#             {
#                 "response_sentence_key": "b.",
#                 "explanation": "This sentence is supported by sentence [0b] in the document 'MERS coronavirus: diagnostics, epidemiology and transmission'.",
#                 "supporting_sentence_keys": [
#                     "[0b]"
#                 ],
#                 "fully_supported": true
#             }
#         ],
#         "all_utilized_sentence_keys": [
#             "[0c]",
#             "[0b]"
#         ]
#     },
#     "analytics_json": {
#         "RMSE-Relevance": 0.8260869565217391,
#         "RMSE-Utililization": 0.536231884057971
#     }
# }```

# %%
import gradio as gr


# Available LLM models
llm_models = ["llama3-8b-8192", "deepseek-r1-distill-llama-70b"]  # Modify as needed
rag_banch_datasets = ['covidqa','cuad','delucionqa','emanual','expertqa',
                      'finqa','hagrid','hotpotqa','msmarco','pubmedqa','tatqa','techqa']

# Gradio Interface
with gr.Blocks() as demo:
    gr.Markdown("## LLM/RAG Query Interface")

    with gr.Row():
        query_input = gr.Textbox(label="Enter your query")
        rag_bench_selector = gr.Dropdown(rag_banch_datasets, label="Select RAG Bench Dataset")
        model_selector = gr.Dropdown(llm_models, label="Select LLM Model")

    submit_btn = gr.Button("Submit")
    answer = gr.Textbox(label="LLM Response", interactive=False)
    res_json = gr.Code(label="LLM Response Evaluation", interactive=False, language="json")

    submit_btn.click(get_response, inputs=[query_input, model_selector, rag_bench_selector], outputs=(answer, res_json))

# Launch the interface
demo.launch(share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://14b15fca1852a5c9e8.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://14b15fca1852a5c9e8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Response from ragbench_collection_techqa for query: JD Edwards Adapter supported in BPM 8.5.6? Hi experts, I have a question about the support for the JD Edwards Adapter in BPM 8.5.6:  which is the most current version of JD Edwards supported in this Adapter ?
# ragbench_collection_techqa has 280 records
# search results size : 1
# Collection: ragbench_collection_techqa, data: {'id': 'ea534f288a26a3b30ebd93e71781948f', 'distance': 0.8435539603233337, 'entity': {'documents': '[0w] [/support/docview.wss?uid=swg27048530&amp;aid=5] Back to Top \n\n\n\nRelated information: \n * Update Strategy for WebSphere Application Server [http://www.ibm.com/support/docview.wss?uid=swg27036014] \n   \n * Fix list for IBM WebSphere Application Server Liberty [http://www.ibm.com/support/docview.wss?uid=swg27043863]\n   \n * CICS TS embedded components [http://www.ibm.com/support/knowledgecenter/SSGMCP_5.3.0/com.ibm.cics.ts.standards.doc/topics/supportedComponents.html]\n   \n * Fixes by version for CICS products [http://www.ibm.com/support/docview.wss?uid=swg27008833]\n\n\n[/support/docview.wss?uid=swg27048530&amp;aid=6] Back to Top \n\n\nPRODUCT ALIAS/SYNONYM\n CICS/TS CICS TS CICS Transaction Server', 'metadata': {'dataset': 'techqa', 'global_index': 9, 'section_index': 0, 'item_index': 22, 'prefix': '0w', 'type': 'Passage'}}}
# Collection: ragbench_collection_techqa, data: {'id': 'f36088268a4bfc6b487d09b3f206ca29', 'distance': 0.8359171152114868, 'entity': {'documents': '[0a]  TECHNOTE (TROUBLESHOOTING)\n\nPROBLEM(ABSTRACT)\n Firefox 38.4 ESR crashes when closing a running Java applet in Windows.', 'metadata': {'dataset': 'techqa', 'global_index': 2, 'section_index': 0, 'item_index': 0, 'prefix': '0a', 'type': 'Title'}}}
# Collection: ragbench_collection_techqa, data: {'id': 'b5423e7cc402306659a755111b648481', 'distance': 0.8265140056610107, 'entity': {'documents': '[4am] * Optionally, verify that the CICS Explorer version has been\n   updated:\n     * Select Help -> About IBM CICS Explorer from the main menu\n   and note the version, it should be now 1.0.0.2.', 'metadata': {'dataset': 'techqa', 'global_index': 9, 'section_index': 4, 'item_index': 39, 'prefix': '4am', 'type': 'Passage'}}}
# Collection: ragbench_collection_techqa, data: {'id': '10c5785508cd9d18f2d78f47e2eec670', 'distance': 0.8264720439910889, 'entity': {'documents': '[0g] to DASH 3.1.3.0 but NOT on DASH 3.1.0.3 (WebGUI\n   8.1.0)\n   \n   Per WebGUI L3, there are no changes in AEL html from 8.1 to 8.1\n   FP4.', 'metadata': {'dataset': 'techqa', 'global_index': 1, 'section_index': 0, 'item_index': 6, 'prefix': '0g', 'type': 'Passage'}}}
# Collection: ragbench_collection_techqa, data: {'id': '9248f0dfcef95af838efbb3843f112df', 'distance': 0.8263386487960815, 'entity': {'documents': '[0d] ENVIRONMENT\nThis issue has been reproduced in Windows environments, using the following JREs: \n\n* Oracle JRE 7: U15, U71, U80, U91\n* Oracle JRE 8: U65\n* IBM JRE7: SR9 FP10\n\nThe issue has not been reproduced using the following JREs:\n\n* Oracle JRE 8: U66-b18\n* IBM JRE7: SR8 FP10, SR9 FP20 with APAR IV78787 \n\n\nDIAGNOSING THE PROBLEM\n1.', 'metadata': {'dataset': 'techqa', 'global_index': 2, 'section_index': 0, 'item_index': 3, 'prefix': '0d', 'type': 'Passage'}}}
# Collection: ragbench_collection_techqa, data: {'id': 'a37e1cb36c9568fe82c13164e4d18f11', 'distance': 0.8244073390960693, 'entity': {'documents': '[0s] Cross reference information Segment Product Component Platform Version Edition Business Integration IBM Business Process Manager Standard Security AIX, Linux, Linux zSeries, Solaris, Windows 8.5.6, 8.5.5, 8.5.0.1, 8.5, 8.0.1.3, 8.0.1.2, 8.0.1.1, 8.0.1, 8.0, 7.5.1.2, 7.5.1.1, 7.5.1, 7.5.0.1, 7.5 Business Integration IBM Business Process Manager Express Security Linux, Linux zSeries, Windows 8.5.6, 8.5.5, 8.5.0.1, 8.5, 8.0.1.3, 8.0.1.2, 8.0.1.1, 8.0.1, 8.0, 7.5.1.2, 7.5.1.1, 7.5.1, 7.5.0.1, 7.5 Business Integration WebSphere Lombardi Edition AIX, HP-UX, Linux, Linux zSeries, Linux/x86, Platform Independent, Solaris, Windows, Windows Vista, Windows XP 7.2.0.5, 7.2.0.4, 7.2.0.3, 7.2.0.2, 7.2.0.1, 7.2', 'metadata': {'dataset': 'techqa', 'global_index': 5, 'section_index': 0, 'item_index': 18, 'prefix': '0s', 'type': 'Passage'}}}
# Collection: ragbench_collection_techqa, data: {'id': 'aba5607d442d5441d0ae50b058d01fbc', 'distance': 0.8226705193519592, 'entity': {'documents': '[0g] If you decide to use the samples, work with your JDE specialist to customize the sample EXE files to suit your JDE implementation.', 'metadata': {'dataset': 'techqa', 'global_index': 7, 'section_index': 0, 'item_index': 6, 'prefix': '0g', 'type': 'Passage'}}}
# Collection: ragbench_collection_techqa, data: {'id': '82f1c7ab962dd335864a68de75776323', 'distance': 0.8214377760887146, 'entity': {'documents': '[0a]  TECHNOTE (TROUBLESHOOTING)\n\nPROBLEM(ABSTRACT)\n IBM Data Studio failed to start after you installed IBM Data Studio Version 4.1.3 on Windows 32-bit.', 'metadata': {'dataset': 'techqa', 'global_index': 6, 'section_index': 0, 'item_index': 0, 'prefix': '0a', 'type': 'Title'}}}
# Collection: ragbench_collection_techqa, data: {'id': '5419eed9b8057e8775fccdbf62038afa', 'distance': 0.8204623460769653, 'entity': {'documents': '[1z] [http://www.ibm.com/i/c.gif] Downloads for the Optim solutions for JD Edwards EnterpriseOne\n\nDownload the Data Growth or Application Retirement solution for JD Edwards, as follows.', 'metadata': {'dataset': 'techqa', 'global_index': 7, 'section_index': 1, 'item_index': 25, 'prefix': '1z', 'type': 'Passage'}}}
# Collection: ragbench_collection_techqa, data: {'id': '98a4c0e8fd092ec8aa794c44c27f95c8', 'distance': 0.819534420967102, 'entity': {'documents': '[0c] RESOLVING THE PROBLEM\nUse IBM Data Studio V4.1.2 on Windows 32-bit.', 'metadata': {'dataset': 'techqa', 'global_index': 6, 'section_index': 0, 'item_index': 2, 'prefix': '0c', 'type': 'Passage'}}}
# Search completed. Found 10 results. in 0.12348484992980957 secs
# results: hybrid_search >>>  [{'collection': 'ragbench_collection_techqa', 'id': '98a4c0e8fd092ec8aa794c44c27f95c8', 'metadata': {'dataset': 'techqa', 'global_index': 6, 'section_index': 0, 'item_index': 2, 'prefix': '0c', 'type': 'Passage'}, 'distance': 0.819534420967102, 'documents': '[0c] RESOLVING THE PROBLEM\nUse IBM Data Studio V4.1.2 on Windows 32-bit.'}, {'collection': 'ragbench_collection_techqa', 'id': '5419eed9b8057e8775fccdbf62038afa', 'metadata': {'dataset': 'techqa', 'global_index': 7, 'section_index': 1, 'item_index': 25, 'prefix': '1z', 'type': 'Passage'}, 'distance': 0.8204623460769653, 'documents': '[1z] [http://www.ibm.com/i/c.gif] Downloads for the Optim solutions for JD Edwards EnterpriseOne\n\nDownload the Data Growth or Application Retirement solution for JD Edwards, as follows.'}, {'collection': 'ragbench_collection_techqa', 'id': '82f1c7ab962dd335864a68de75776323', 'metadata': {'dataset': 'techqa', 'global_index': 6, 'section_index': 0, 'item_index': 0, 'prefix': '0a', 'type': 'Title'}, 'distance': 0.8214377760887146, 'documents': '[0a]  TECHNOTE (TROUBLESHOOTING)\n\nPROBLEM(ABSTRACT)\n IBM Data Studio failed to start after you installed IBM Data Studio Version 4.1.3 on Windows 32-bit.'}, {'collection': 'ragbench_collection_techqa', 'id': 'aba5607d442d5441d0ae50b058d01fbc', 'metadata': {'dataset': 'techqa', 'global_index': 7, 'section_index': 0, 'item_index': 6, 'prefix': '0g', 'type': 'Passage'}, 'distance': 0.8226705193519592, 'documents': '[0g] If you decide to use the samples, work with your JDE specialist to customize the sample EXE files to suit your JDE implementation.'}, {'collection': 'ragbench_collection_techqa', 'id': 'a37e1cb36c9568fe82c13164e4d18f11', 'metadata': {'dataset': 'techqa', 'global_index': 5, 'section_index': 0, 'item_index': 18, 'prefix': '0s', 'type': 'Passage'}, 'distance': 0.8244073390960693, 'documents': '[0s] Cross reference information Segment Product Component Platform Version Edition Business Integration IBM Business Process Manager Standard Security AIX, Linux, Linux zSeries, Solaris, Windows 8.5.6, 8.5.5, 8.5.0.1, 8.5, 8.0.1.3, 8.0.1.2, 8.0.1.1, 8.0.1, 8.0, 7.5.1.2, 7.5.1.1, 7.5.1, 7.5.0.1, 7.5 Business Integration IBM Business Process Manager Express Security Linux, Linux zSeries, Windows 8.5.6, 8.5.5, 8.5.0.1, 8.5, 8.0.1.3, 8.0.1.2, 8.0.1.1, 8.0.1, 8.0, 7.5.1.2, 7.5.1.1, 7.5.1, 7.5.0.1, 7.5 Business Integration WebSphere Lombardi Edition AIX, HP-UX, Linux, Linux zSeries, Linux/x86, Platform Independent, Solaris, Windows, Windows Vista, Windows XP 7.2.0.5, 7.2.0.4, 7.2.0.3, 7.2.0.2, 7.2.0.1, 7.2'}, {'collection': 'ragbench_collection_techqa', 'id': '9248f0dfcef95af838efbb3843f112df', 'metadata': {'dataset': 'techqa', 'global_index': 2, 'section_index': 0, 'item_index': 3, 'prefix': '0d', 'type': 'Passage'}, 'distance': 0.8263386487960815, 'documents': '[0d] ENVIRONMENT\nThis issue has been reproduced in Windows environments, using the following JREs: \n\n* Oracle JRE 7: U15, U71, U80, U91\n* Oracle JRE 8: U65\n* IBM JRE7: SR9 FP10\n\nThe issue has not been reproduced using the following JREs:\n\n* Oracle JRE 8: U66-b18\n* IBM JRE7: SR8 FP10, SR9 FP20 with APAR IV78787 \n\n\nDIAGNOSING THE PROBLEM\n1.'}, {'collection': 'ragbench_collection_techqa', 'id': '10c5785508cd9d18f2d78f47e2eec670', 'metadata': {'dataset': 'techqa', 'global_index': 1, 'section_index': 0, 'item_index': 6, 'prefix': '0g', 'type': 'Passage'}, 'distance': 0.8264720439910889, 'documents': '[0g] to DASH 3.1.3.0 but NOT on DASH 3.1.0.3 (WebGUI\n   8.1.0)\n   \n   Per WebGUI L3, there are no changes in AEL html from 8.1 to 8.1\n   FP4.'}, {'collection': 'ragbench_collection_techqa', 'id': 'b5423e7cc402306659a755111b648481', 'metadata': {'dataset': 'techqa', 'global_index': 9, 'section_index': 4, 'item_index': 39, 'prefix': '4am', 'type': 'Passage'}, 'distance': 0.8265140056610107, 'documents': '[4am] * Optionally, verify that the CICS Explorer version has been\n   updated:\n     * Select Help -> About I ...
# Hybrid Search completed. Found 10 results (approx. 2 * 10 + alpha * 10). in 0.5264105796813965 secs
# retrieve_docs_milvus >>> documents_list from Hybrid + HyDE search >>>> ['[0c] RESOLVING THE PROBLEM\nUse IBM Data Studio V4.1.2 on Windows 32-bit.', '[1z] [http://www.ibm.com/i/c.gif] Downloads for the Optim solutions for JD Edwards EnterpriseOne\n\nDownload the Data Growth or Application Retirement solution for JD Edwards, as follows.', '[0a]  TECHNOTE (TROUBLESHOOTING)\n\nPROBLEM(ABSTRACT)\n IBM Data Studio failed to start after you installed IBM Data Studio Version 4.1.3 on Windows 32-bit.', '[0g] If you decide to use the samples, work with your JDE specialist to customize the sample EXE files to suit your JDE implementation.', '[0s] Cross reference information Segment Product Component Platform Version Edition Business Integration IBM Business Process Manager Standard Security AIX, Linux, Linux zSeries, Solaris, Windows 8.5.6, 8.5.5, 8.5.0.1, 8.5, 8.0.1.3, 8.0.1.2, 8.0.1.1, 8.0.1, 8.0, 7.5.1.2, 7.5.1.1, 7.5.1, 7.5.0.1, 7.5 Business Integration IBM Business Process Manager Express Security Linux, Linux zSeries, Windows 8.5.6, 8.5.5, 8.5.0.1, 8.5, 8.0.1.3, 8.0.1.2, 8.0.1.1, 8.0.1, 8.0, 7.5.1.2, 7.5.1.1, 7.5.1, 7.5.0.1, 7.5 Business Integration WebSphere Lombardi Edition AIX, HP-UX, Linux, Linux zSeries, Linux/x86, Platform Independent, Solaris, Windows, Windows Vista, Windows XP 7.2.0.5, 7.2.0.4, 7.2.0.3, 7.2.0.2, 7.2.0.1, 7.2', '[0d] ENVIRONMENT\nThis issue has been reproduced in Windows environments, using the following JREs: \n\n* Oracle JRE 7: U15, U71, U80, U91\n* Oracle JRE 8: U65\n* IBM JRE7: SR9 FP10\n\nThe issue has not been reproduced using the following JREs:\n\n* Oracle JRE 8: U66-b18\n* IBM JRE7: SR8 FP10, SR9 FP20 with APAR IV78787 \n\n\nDIAGNOSING THE PROBLEM\n1.', '[0g] to DASH 3.1.3.0 but NOT on DASH 3.1.0.3 (WebGUI\n   8.1.0)\n   \n   Per WebGUI L3, there are no changes in AEL html from 8.1 to 8.1\n   FP4.', '[4am] * Optionally, verify that the CICS Explorer version has been\n   updated:\n     * Select Help -> About IBM CICS Explorer from the main menu\n   and note the version, it should be now 1.0.0.2.', '[0a]  TECHNOTE (TROUBLESHOOTING)\n\nPROBLEM(ABSTRACT)\n Firefox 38.4 ESR crashes when closing a running Java applet in Windows.', '[0w] [/support/docview.wss?uid=swg27048530&amp;aid=5] Back to Top \n\n\n\nRelated information: \n * Update Strategy for WebSphere Application Server [http://www.ibm.com/support/docview.wss?uid=swg27036014] \n   \n * Fix list for IBM WebSphere Application Server Liberty [http://www.ibm.com/support/docview.wss?uid=swg27043863]\n   \n * CICS TS embedded components [http://www.ibm.com/support/knowledgecenter/SSGMCP_5.3.0/com.ibm.cics.ts.standards.doc/topics/supportedComponents.html]\n   \n * Fixes by version for CICS products [http://www.ibm.com/support/docview.wss?uid=swg27008833]\n\n\n[/support/docview.wss?uid=swg27048530&amp;aid=6] Back to Top \n\n\nPRODUCT ALIAS/SYNONYM\n CICS/TS CICS TS CICS Transaction Server']
# context>>>from 1st RAG>>>>>>  [0c] RESOLVING THE PROBLEM
# Use IBM Data Studio V4.1.2 on Windows 32-bit.[1z] [http://www.ibm.com/i/c.gif] Downloads for the Optim solutions for JD Edwards EnterpriseOne
#
# Download the Data Growth or Application Retirement solution for JD Edwards, as follows.[0a]  TECHNOTE (TROUBLESHOOTING)
#
# PROBLEM(ABSTRACT)
#  IBM Data Studio failed to start after you installed IBM Data Studio Version 4.1.3 on Windows 32-bit.[0g] If you decide to use the samples, work with your JDE specialist to customize the sample EXE files to suit your JDE implementation.[0s] Cross reference information Segment Product Component Platform Version Edition Business Integration IBM Business Process Manager Standard Security AIX, Linux, Linux zSeries, Solaris, Windows 8.5.6, 8.5.5, 8.5.0.1, 8.5, 8.0.1.3, 8.0.1.2, 8.0.1.1, 8.0.1, 8.0, 7.5.1.2, 7.5.1.1, 7.5.1, 7.5.0.1, 7.5 Business Integration IBM Business Process Manager Express Security Linux, Linux zSeries, Windows 8.5.6, 8.5.5, 8.5.0.1, 8.5, 8.0.1.3, 8.0.1.2, 8.0.1.1, 8.0.1, 8.0, 7.5.1.2, 7.5.1.1, 7.5.1, 7.5.0.1, 7.5 Business Integration WebSphere Lombardi Edition AIX, HP-UX, Linux, Linux zSeries, Linux/x86, Platform Independent, Solaris, Windows, Windows Vista, Windows XP 7.2.0.5, 7.2.0.4, 7.2.0.3, 7.2.0.2, 7.2.0.1, 7.2[0d] ENVIRONMENT
# This issue has been reproduced in Windows environments, using the following JREs:
#
# * Oracle JRE 7: U15, U71, U80, U91
# * Oracle JRE 8: U65
# * IBM JRE7: SR9 FP10
#
# The issue has not been reproduced using the following JREs:
#
# * Oracle JRE 8: U66-b18
# * IBM JRE7: SR8 FP10, SR9 FP20 with APAR IV78787
#
#
# DIAGNOSING THE PROBLEM
# 1.[0g] to DASH 3.1.3.0 but NOT on DASH 3.1.0.3 (WebGUI
#    8.1.0)
#
#    Per WebGUI L3, there are no changes in AEL html from 8.1 to 8.1
#    FP4.[4am] * Optionally, verify that the CICS Explorer version has been
#    updated:
#      * Select Help -> About IBM CICS Explorer from the main menu
#    and note the version, it should be now 1.0.0.2.[0a]  TECHNOTE (TROUBLESHOOTING)
#
# PROBLEM(ABSTRACT)
#  Firefox 38.4 ESR crashes when closing a running Java applet in Windows.[0w] [/support/docview.wss?uid=swg27048530&amp;aid=5] Back to Top
#
#
#
# Related information:
#  * Update Strategy for WebSphere Application Server [http://www.ibm.com/support/docview.wss?uid=swg27036014]
#
#  * Fix list for IBM WebSphere Application Server Liberty [http://www.ibm.com/support/docview.wss?uid=swg27043863]
#
#  * CICS TS embedded components [http://www.ibm.com/support/knowledgecenter/SSGMCP_5.3.0/com.ibm.cics.ts.standards.doc/topics/supportedComponents.html]
#
#  * Fixes by version for CICS products [http://www.ibm.com/support/docview.wss?uid=swg27008833]
#
#
# [/support/docview.wss?uid=swg27048530&amp;aid=6] Back to Top
#
#
# PRODUCT ALIAS/SYNONYM
#  CICS/TS CICS TS CICS Transaction Server
# groq_response>>>from 1st RAG>>>>>>  According to the provided documents, the JD Edwards Adapter is not explicitly mentioned in the context of IBM Data Studio V4.1.2 or BPM 8.5.6. However, the documents do mention the following:
#
# * The JD Edwards EnterpriseOne solution is available for download from the IBM website.
# * The JD Edwards Adapter is not mentioned in the troubleshooting documents or the product alias/synonym list.
#
# Therefore, it is not possible to determine the most current version of JD Edwards supported in the JD Edwards Adapter in BPM 8.5.6 based on the provided information.
# train-00000-of-00001.parquet:   0%|          | 0.00/22.5M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/5.40M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/5.35M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1192 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/304 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/314 [00:00<?, ? examples/s]
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://14b15fca1852a5c9e8.gradio.live
